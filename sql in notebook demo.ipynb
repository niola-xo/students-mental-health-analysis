# %%
# !pip install pandas
# !pip install numpy
import pandas as pd
import numpy as np
import sqlite3
# Out:
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# 'pip' is not recognized as an internal or external command,
# operable program or batch file.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 get_ipython().system('pip install pandas')
#       2 get_ipython().system('pip install numpy')
# ----> 3 import pandas as pd
#       4 import numpy as np
#       5 import sqlite3
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data = pd.read_csv('student_mh_data.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10352\3692214543.py in <module>
# ----> 1 data = pd.read_csv('student_mh_data.csv')
#       2 data
#
# c:\Users\hp\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# !pip install ipython-sql

# %%
cnn = sqlite3.connect('database.db')

# %%
data.to_sql('students', cnn)
# Out:
# 286

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql sqlite:///database.db

# %%
# %%sql
# SELECT *
# FROM students
# LIMIT 10
# Out:
#    sqlite://
#    sqlite:///data.db
#  * sqlite:///database.db
# Done.
# [(0, 'Inter', 'SEA', 'Male', 'Grad', 24.0, 4.0, 5.0, 'Long', 3.0, 'Average', 5.0, 'High', None, 'Yes', 'No', 'No', 'No', 0.0, 'Min', 34.0, 23.0, 9.0, 11.0, 8.0, 11.0, 2.0, 27.0, 91.0, 5.0, 5.0, 6.0, 3.0, 2.0, 1.0, 4.0, 1.0, 3.0, 4.0, None, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
#  (1, 'Inter', 'SEA', 'Male', 'Grad', 28.0, 5.0, 1.0, 'Short', 4.0, 'High', 4.0, 'High', None, 'No', 'No', 'No', 'No', 2.0, 'Min', 48.0, 8.0, 7.0, 5.0, 4.0, 3.0, 2.0, 10.0, 39.0, 7.0, 7.0, 7.0, 4.0, 4.0, 4.0, 4.0, 1.0, 1.0, 1.0, None, 'Yes', 'Yes', 'Yes', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
#  (2, 'Inter', 'SEA', 'Male', 'Grad', 25.0, 4.0, 6.0, 'Long', 4.0, 'High', 4.0, 'High', 'Yes', 'Yes', 'No', 'No', 'No', 2.0, 'Min', 41.0, 13.0, 4.0, 7.0, 6.0, 4.0, 3.0, 14.0, 51.0, 3.0, 3.0, 3.0, 1.0, 1.0, 2.0, 1.0, 1.0, 1.0, 1.0, None, 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No'),
# ...

# %%
# %%sql
# SELECT COUNT(*) total_records
# FROM students
# Out:
#    sqlite://
#    sqlite:///data.db
#  * sqlite:///database.db
# Done.
# [(286,)]
